# %%
import numpy as np
import pandas as pd
import seaborn as sn
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Final_data=pd.read_csv('C:/Users/User/Desktop/Praxis Business School/Term1/STS/STS Project/Manas STS/STS Final Dataset 3.csv')

# %%
Final_data.shape
# Out:
# (29, 5)

# %%
sn.pairplot(Final_data)

# %%
corrmat=Final_data.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(20,20))
#plot the heat map
g=sn.heatmap(Final_data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
sn.boxplot(Final_data['Per Capita GSDP(Current Price Rs)'])
# Out:
# <AxesSubplot:xlabel='Per Capita GSDP(Current Price Rs)'>

# %%
sn.boxplot(Final_data['Birth Rate'])
# Out:
# <AxesSubplot:xlabel='Birth Rate'>

# %%
sn.boxplot(Final_data['Death Rate'])
# Out:
# <AxesSubplot:xlabel='Death Rate'>

# %%
sn.boxplot(Final_data['Infant Mortality rate'])
# Out:
# <AxesSubplot:xlabel='Infant Mortality rate'>

# %%
Final_data['Birth Rate'].mean()
# Out:
# 17.75862068965517

# %%
Final_data['Birth Rate'].median()
# Out:
# 16.7

# %%
Final_data['Birth Rate'].describe()
# Out:
# count    29.000000
# mean     17.758621
# std       4.129382
# min      12.300000
# 25%      14.500000
# 50%      16.700000
# 75%      21.000000
# max      25.800000
# Name: Birth Rate, dtype: float64

# %%
Final_data['Death Rate'].mean()
# Out:
# 5.768965517241378

# %%
Final_data['Death Rate'].median()
# Out:
# 5.9

# %%
Final_data['Death Rate'].describe()
# Out:
# count    29.000000
# mean      5.768966
# std       0.950603
# min       3.500000
# 25%       5.400000
# 50%       5.900000
# 75%       6.400000
# max       7.300000
# Name: Death Rate, dtype: float64

# %%
Final_data['Infant Mortality rate'].mean()
# Out:
# 23.17241379310345

# %%
Final_data['Infant Mortality rate'].median()
# Out:
# 23.0

# %%
Final_data['Infant Mortality rate'].describe()
# Out:
# count    29.000000
# mean     23.172414
# std      11.940534
# min       3.000000
# 25%      17.000000
# 50%      23.000000
# 75%      29.000000
# max      46.000000
# Name: Infant Mortality rate, dtype: float64

# %%
Final_data['Per Capita GSDP(Current Price Rs)'].mean()
# Out:
# 186257.6551724138

# %%
Final_data['Per Capita GSDP(Current Price Rs)'].median()
# Out:
# 164557.0

# %%
Final_data['Per Capita GSDP(Current Price Rs)'].describe()
# Out:
# count        29.000000
# mean     186257.655172
# std      107956.256565
# min       50735.000000
# 25%      117700.000000
# 50%      164557.000000
# 75%      243189.000000
# max      520030.000000
# Name: Per Capita GSDP(Current Price Rs), dtype: float64
